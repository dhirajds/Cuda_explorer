# %% [markdown]
# <a href="https://colab.research.google.com/github/dhirajds/Cuda_explorer/blob/explore_cuda/1_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# ...
# Detected platform "Colab". Running its setup...
# Source files will be saved in "/tmp/tmpz_mky12y".

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %%
# %%writefile check_cuda.cu
# #include <stdio.h>
# #include <cuda_runtime.h>
#
# __global__ void hello_from_gpu() {
#     printf("Hello from GPU! Block %d, Thread %d\n", blockIdx.x, threadIdx.x);
# }
#
# int main() {
#     printf("Launching kernel...\n"); // Diagnostic print
#     // Launch kernel with 2 blocks, each with 2 threads
#     printf("hello");
#     hello_from_gpu<<<2, 2>>>();
#
#     // Flush stdout to ensure GPU output is printed
#     fflush(stdout);
#
#     // Wait for GPU to finish before accessing results
#     cudaError_t err = cudaDeviceSynchronize();
#
#     if (err != cudaSuccess) {
#         printf("CUDA error: %s\n", cudaGetErrorString(err));
#     } else {
#         printf("Kernel finished successfully.\n"); // Diagnostic print
#     }
#
#     return 0;
# }
# Out:
# Overwriting check_cuda.cu

# %%
# !nvcc check_cuda.cu -o check_cuda

# %%
# !./check_cuda
# Out:
# Launching kernel...
# helloKernel finished successfully.
